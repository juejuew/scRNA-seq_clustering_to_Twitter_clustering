# %%
library(dplyr)
library(useful)
library(Seurat)
library(patchwork)
library(cluster)
library(ggplot2)
library(randomNames)
library(tidyverse)
library(data.table)
library(lubridate)
library(ggplot2)
library(stringr)
library(monocle3)
library(reshape2)
library(pairwise)
library(scales)

# %%
# Define the hand-classification function 
# Input: (1) row: one row of the document metadata
# Output: (1) label of the corresponding tweet from the hand-classification criteria

hc_classify = function(row){
  
  tweetl = tolower(row$tweet)
  user_name = tolower(row$user)
  
  #1.
  junk_words = c("steve", "apple", "iphone", "itunes", "ipad", "mac", "wozniak", "gates", "dirty", "blow", "hand",
                 "whack", "nut")
  for(i in 1:length(junk_words)){
    if(grepl(junk_words[i], tweetl, fixed=TRUE)){
      return("Junk")
    }
  }
  
  #2. 
  ad_word = c("#hiring", "#jobs")
  user_ad_word = c("job", "tmj", "career")
  for(i in 1:length(ad_word)){
    if(grepl(ad_word[i], tweetl, fixed=TRUE)){
      return("Advertisement")
    }
  }
  
  for(i in 1:length(user_ad_word)){
    if(grepl(user_ad_word[i], user_name, fixed=TRUE)){
      return("Advertisement")
    }
  }
  
  #3. 
  news_word = c("obama", "clinton", "trump", "mcconnell", "ryan", "boehner", "potus", "cantor",
                "palin", "teaparty", "democrat", "repbulic", "mccain", "romney", "trade", "taxes", "senate", "president", "gop")
  user_news_word = c("news")
  for(i in 1:length(news_word)){
    if(grepl(news_word[i], tweetl, fixed=TRUE)){
      return("News/Politics")
    }
  }
  
  for(i in 1:length(user_news_word)){
    if(grepl(user_news_word[i], user_name, fixed=TRUE)){
      return("News/Politics")
    }
  }
  
  #4.
  url_pattern <- "http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+"
  if(grepl(url_pattern, tweetl)){
     return("Other")
  }
  
  #5.
  return("Personal")
}

# %%
# load hand-classified data for evaluation 
doc_metadata = read.csv("/home/rep/scRNA-seq_clustering_to_Twitter/P3_Proposed_workflow/PW_files/hand_classified_jobs.csv") %>% select(-X)

# %%
# run HCCA function
type = vector()
for(i in 1:nrow(doc_metadata)){
  row = doc_metadata[i,]
  type[i] = hc_classify(row)
  
}

doc_metadata = doc_metadata %>% mutate(HCCA_category = type)

# %%
# generate numerical labels 
doc_metadata = doc_metadata %>% dplyr::mutate(true_label = ifelse(cat == "Junk", 1, 
                                                             ifelse(cat == "Advertisement", 2,
                                                                    ifelse(cat == "News/Politics", 3, 
                                                                           ifelse(cat == "Other", 4, 5)))))
doc_metadata = doc_metadata %>% dplyr::mutate(HCCA_label = ifelse(HCCA_category == "Junk", 1, 
                                                             ifelse(HCCA_category == "Advertisement", 2,
                                                                    ifelse(HCCA_category == "News/Politics", 3, 
                                                                           ifelse(HCCA_category == "Other", 4, 5)))))

# %%
doc_metadata
# Out:
#     user
# 1   Accounting jobs
# 2   TMJ-SAT Retail Jobs
# 3   Dallas jobs
# 4   Massachusetts Jobs
# 5   ☆Assata☆
# 6   Emerson
# 7   Kansas City Jobs
# 8   WA Nursing Jobs
# 9   Hospitality US
# 10  Caleb Denney
# 11  Accounting US
# 12  Baltimore Jobs
# 13  TMJ-HOU Retail Jobs
# 14  Jennifer Couch
# 15  C Mack
# 16  Jobs Brentwood
# 17  CPEC1031
# 18  Orlando Jobs
# 19  ZipRecruiter Jobs
# 20  Bridgeport Careers
# 21  TMJ-WA HRTA Jobs
# 22  Chicago Jobs
# 23  Neuvoo Cleveland
# 24  Jobs New Orleans
# 25  BeeJobs.me 1M
# 26  IT Jobs Nashville
# 27  Jobs in Louisville
# 28  Accounting New York
# 29  Retail Jobs New York
# 30  smashbucks
# ⋮   ⋮
# 767 abnerg
# 768 aepette
# 769 heyMcGarry
# 770 GrandRapidsJob_
# 771 kellijobowles
# 772 Alethiabg44
# 773 humancell
# 774 JobsSanAntonio
# 775 NewZealandJobs2
# 776 GO2UKJobs
# 777 nullpoint
# 778 Grrrrr_AhhhFuck
# 779 jes523
# 780 danielpunkass
# 781 Kingman_Jobs
# 782 AdsInPakistan
# 783 0investor
# 784 AlishaEvinger
# 785 rubibo8
# 786 DmitriGunn
# 787 Alexa
# 788 mesasudjai
# 789 LouisAndrews9
# 790 sarahishiring
# 791 GetReceptioJobs
# 792 haruszpapa
# 793 TravelManager1
# 794 magneda2
# 795 price_laborecon
# 796 A5Whatever
#     tweet
# 1   #jobs4u #jobs ACCOUNTING CLERK, [Baton Rouge, #LA] http://t.co/YbwCFQK1ma #accounting
# 2   This tweet has been removed in accordance with Twitter's policy. Twitter requires all its partners to remove tweets from their systems as soon as they are deleted on Twitter itself.
# 3   #jobs4u #jobs Construction Project Manager - Retail Division http://t.co/uxm5CfHf7m #DAL #dallas #TX
# 4   Recruiter needed in #Braintree, #MA https://t.co/0kBNf0C5lW #jobs #hiring
# 5   @CTheLily Lol oh girl I aint goin down there anytime soon ....... not until one of these jobs have contacted me ..... I'm lookin for cheap
# 6   This tweet has been removed in accordance with Twitter's policy. Twitter requires all its partners to remove tweets from their systems as soon as they are deleted on Twitter itself.
# 7   #KansasCity #Jobs Java.lang. Integer/3438268---: Kansas City Accountemps, a Robert Half company, is the world'... http://t.co/qy7ztfgRbD
# 8   This tweet has been removed in accordance with Twitter's policy. Twitter requires all its partners to remove tweets from their systems as soon as they are deleted on Twitter itself.
# 9   New #job opening at ABM Building Value in #Norwalk - #Cleaner #jobs http://t.co/AC7PhwQjJn
# 10  @kbirge Stumbled upon you because the Colts retweeted you. Read your bio. What do you mean you want to bring tech jobs to Indiana? Curious
# 11  Resume Library is looking for a #Tax #Partner in #, apply now! #jobs http://t.co/OUwqP7ukwl
# 12  Professional Sales Person Jobs in Baltimore, MD #Baltimore #MD #jobs #jobsearch https://t.co/kM2Y5w3fw9
# 2   Advertisement Advertisement 2          2
# 3   Advertisement Advertisement 2          2
# 4   Advertisement Advertisement 2          2
# 5   Personal      Personal      5          5
# 6   Advertisement Personal      2          5
# 7   Advertisement Advertisement 2          2
# 8   Advertisement Advertisement 2          2
# 9   Advertisement Advertisement 2          2
# 10  Personal      Personal      5          5
# 11  Advertisement Advertisement 2          2
# 12  Advertisement Advertisement 2          2
# 13  Advertisement Advertisement 2          2
# 14  Other         Other         4          4
# 15  Personal      Personal      5          5
# 16  Advertisement Advertisement 2          2
# 17  News/Politics Other         3          4
# 18  Advertisement Advertisement 2          2
# 19  Advertisement Advertisement 2          2
# 20  Advertisement Advertisement 2          2
# 21  Advertisement Advertisement 2          2
# 22  Advertisement Advertisement 2          2
# 23  Advertisement Advertisement 2          2
# 24  Advertisement Advertisement 2          2
# 25  Advertisement Advertisement 2          2
# 26  Advertisement Advertisement 2          2
# 27  Advertisement Advertisement 2          2
# 28  Advertisement Advertisement 2          2
# 29  Advertisement Junk          2          1
# 30  Junk          Junk          1          1
# ⋮   ⋮             ⋮             ⋮          ⋮
# 767 Advertisement Other         2          4
# 768 News/Politics Other         3          4
# 769 Junk          Junk          1          1
# 770 Advertisement Advertisement 2          2
# 771 Personal      Advertisement 5          2
# 772 Advertisement Other         2          4
# 773 Advertisement Personal      2          5
# 774 Advertisement Advertisement 2          2
# 775 Advertisement Advertisement 2          2
# 776 Advertisement Advertisement 2          2
# 777 News/Politics Personal      3          5
# 778 Personal      Personal      5          5
# 779 Personal      Personal      5          5
# 780 Personal      Personal      5          5
# 781 Advertisement Advertisement 2          2
# 782 Advertisement Other         2          4
# 783 Advertisement Other         2          4
# 784 Junk          Junk          1          1
# 785 Other         Other         4          4
# 786 Junk          Junk          1          1
# 787 Personal      Personal      5          5
# 788 Advertisement Other         2          4
# 789 Junk          Junk          1          1
# 790 News/Politics Other         3          4
# 791 Advertisement Advertisement 2          2
# 792 Junk          Junk          1          1
# 793 News/Politics Other         3          4
# 794 News/Politics Other         3          4
# 795 Other         Personal      4          5
# 796 Junk          Junk          1          1

# %%
# Contingency table
doc_metadata$true_category = doc_metadata$cat 
doc_metadata = doc_metadata %>% select(-cat)
df_compare = doc_metadata %>% mutate(HCCA_results = doc_metadata$HCCA_category)
organize = df_compare  %>% dplyr::count(true_category, HCCA_results)  
contingency_table = spread(organize, true_category, n, fill = 0, convert = FALSE)
contingency_table
# Out:
#   HCCA_results  Advertisement Junk News/Politics Other Personal
# 1 Advertisement 294            1    6             3      4
# 2 Junk            9           75    5             0      3
# 3 News/Politics   6            0   42             1      3
# 4 Other          64            4   39            31      6
# 5 Personal       20           11   39            16    114

# %%
# write.csv(doc_metadata, "/home/rep/scRNA-seq_clustering_to_Twitter/P3_Proposed_workflow/PW_files/doc_metadata_stemming_valijobs_hclabeled.csv")
